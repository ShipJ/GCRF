# %%
# Log Log transform
print 'Activity PMCC:'
non_outliers_1 = np.intersect1d(np.where(activity_1['Vol'] > 0), np.where(activity_1['Vol'] < 100))

print pearsonr(np.log(activity_1['Vol'][non_outliers_1])/max(np.log(activity_1['Vol'][non_outliers_1])),
               np.log(hiv_1['HIV_rate'][non_outliers_1])/min(np.log(hiv_1['HIV_rate'][non_outliers_1])))
plt.scatter(np.log(activity_1['Vol'][non_outliers_1])/max(np.log(activity_1['Vol'][non_outliers_1])),
               np.log(hiv_1['HIV_rate'][non_outliers_1])/min(np.log(hiv_1['HIV_rate'][non_outliers_1])))
applyPlotStyle()
plt.xlabel('Activity Adm_1')
plt.ylabel('HIV Cases Per Person')
plt.show()

non_outliers_2 = np.intersect1d(np.intersect1d(np.where(activity_2['Vol'] > 8), np.where(activity_2['Vol'] < 80)),
                                np.where(hiv_2['HIV_rate'] > 0))
print pearsonr(np.log(activity_2['Vol'][non_outliers_2])/max(np.log(activity_2['Vol'][non_outliers_2])),
               np.log(hiv_2['HIV_rate'][non_outliers_2])/min(np.log(hiv_2['HIV_rate'][non_outliers_2])))
plt.scatter(np.log(activity_2['Vol'][non_outliers_2])/max(np.log(activity_2['Vol'][non_outliers_2])),
               np.log(hiv_2['HIV_rate'][non_outliers_2])/min(np.log(hiv_2['HIV_rate'][non_outliers_2])))
applyPlotStyle()
plt.xlabel('Activity Adm_2')
plt.ylabel('HIV Cases Per Person')
plt.show()

non_outliers_3 = np.intersect1d(np.intersect1d(np.where(activity_3['Vol'] > 0), np.where(activity_3['Vol'] < 100)),
                                np.intersect1d(np.where(hiv_3['HIV_rate'] > 0.002), np.where(hiv_3['HIV_rate'] < 0.08)))
print pearsonr(np.log(np.array(activity_3['Vol'])[non_outliers_3])/max(np.log(np.array(activity_3['Vol'])[non_outliers_3])),
               np.log(np.array(hiv_3['HIV_rate'])[non_outliers_3])/min(np.log(np.array(hiv_3['HIV_rate'])[non_outliers_3])))

plt.scatter(np.log(np.array(activity_3['Vol'])[non_outliers_3])/max(np.log(np.array(activity_3['Vol'])[non_outliers_3])),
               np.log(np.array(hiv_3['HIV_rate'])[non_outliers_3])/min(np.log(np.array(hiv_3['HIV_rate'])[non_outliers_3])))
applyPlotStyle()
plt.xlabel('Activity Adm_3')
plt.ylabel('HIV Cases Per Person')
plt.show()

non_outliers_4 = np.intersect1d(np.intersect1d(np.where(activity_4['Vol'] > 0), np.where(activity_4['Vol'] < 100)), 
                                np.intersect1d(np.where(hiv_4['HIV_rate'] > 0.002), np.where(hiv_4['HIV_rate'] < 0.08)))
print pearsonr(np.log(np.array(activity_4['Vol'])[non_outliers_4])/max(np.log(np.array(activity_4['Vol'])[non_outliers_4])),
               np.log(np.array(hiv_4['HIV_rate'])[non_outliers_4])/min(np.log(np.array(hiv_4['HIV_rate'])[non_outliers_4])))

plt.scatter(np.log(np.array(activity_4['Vol'])[non_outliers_4])/max(np.log(np.array(activity_4['Vol'])[non_outliers_4])),
               np.log(np.array(hiv_4['HIV_rate'])[non_outliers_4])/min(np.log(np.array(hiv_4['HIV_rate'])[non_outliers_4])))
applyPlotStyle()
plt.xlabel('Activity Adm_4')
plt.ylabel('HIV Cases Per Person')
plt.show()


# Log Linear transform
print 'Activity PMCC:'
non_outliers_1 = np.intersect1d(np.where(activity_1['Vol'] > 0), np.where(activity_1['Vol'] < 100))

print pearsonr(np.log(activity_1['Vol'][non_outliers_1])/max(activity_1['Vol'][non_outliers_1]),
               hiv_1['HIV_rate'][non_outliers_1]/max(hiv_1['HIV_rate'][non_outliers_1]))
plt.scatter(np.log(activity_1['Vol'][non_outliers_1])/max(activity_1['Vol'][non_outliers_1]),
               hiv_1['HIV_rate'][non_outliers_1]/max(hiv_1['HIV_rate'][non_outliers_1]))
plt.xlabel('Activity Adm_1')
plt.ylabel('HIV Cases Per Person')
plt.show()

non_outliers_2 = np.intersect1d(np.intersect1d(np.where(activity_2['Vol'] > 8), np.where(activity_2['Vol'] < 80)),
                                np.where(hiv_2['HIV_rate'] > 0))
print pearsonr(np.log(activity_2['Vol'][non_outliers_2])/max(activity_2['Vol'][non_outliers_2]),
               hiv_2['HIV_rate'][non_outliers_2]/max(hiv_2['HIV_rate'][non_outliers_2]))
plt.scatter(np.log(activity_2['Vol'][non_outliers_2])/max(activity_2['Vol'][non_outliers_2]),
               hiv_2['HIV_rate'][non_outliers_2]/max(hiv_2['HIV_rate'][non_outliers_2]))
plt.xlabel('Activity Adm_2')
plt.ylabel('HIV Cases Per Person')
plt.show()

non_outliers_3 = np.intersect1d(np.intersect1d(np.where(activity_3['Vol'] > 0), np.where(activity_3['Vol'] < 100)),
                                np.intersect1d(np.where(hiv_3['HIV_rate'] > 0.002), np.where(hiv_3['HIV_rate'] < 0.08)))
print pearsonr(np.log(np.array(activity_3['Vol'])[non_outliers_3])/max(np.array(activity_3['Vol'])[non_outliers_3]),
               np.array(hiv_3['HIV_rate'][non_outliers_3])/max(np.array(hiv_3['HIV_rate'])[non_outliers_3]))

plt.scatter(np.log(np.array(activity_3['Vol'])[non_outliers_3])/max(np.array(activity_3['Vol'])[non_outliers_3]),
               np.array(hiv_3['HIV_rate'][non_outliers_3])/max(np.array(hiv_3['HIV_rate'])[non_outliers_3]))
plt.xlabel('Activity Adm_3')
plt.ylabel('HIV Cases Per Person')
plt.show()

non_outliers_4 = np.intersect1d(np.intersect1d(np.where(activity_4['Vol'] > 0), np.where(activity_4['Vol'] < 100)),
                                np.intersect1d(np.where(hiv_4['HIV_rate'] > 0.002), np.where(hiv_4['HIV_rate'] < 0.08)))
print pearsonr(np.log(np.array(activity_4['Vol'])[non_outliers_4])/max(np.array(activity_4['Vol'])[non_outliers_4]),
               np.array(hiv_4['HIV_rate'][non_outliers_4])/max(np.array(hiv_4['HIV_rate'])[non_outliers_4]))

plt.scatter(np.log(np.array(activity_4['Vol'])[non_outliers_4])/max(np.array(activity_4['Vol'])[non_outliers_4]),
               np.array(hiv_4['HIV_rate'][non_outliers_4])/max(np.array(hiv_4['HIV_rate'])[non_outliers_4]))
plt.xlabel('Activity Adm_4')
plt.ylabel('HIV Cases Per Person')
plt.show()
